# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaykumar2972/POC2025/blob/main/Processing_data_for_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('df_Clustering.csv')

# %% [markdown]
# ## **Clustering**

# %% [markdown]
# #### **Dropping all columns which doesn't add any value for further and created for understanding the dataset**

# %%
df.drop(columns=['CustomerId'
                , 'EnrolledDate'
                , 'Year_Birth'
                , 'Age_Group'
                , 'TotalAmountSpent'
                , 'TotalPurchasesCount'
                , 'AverageSpendPerPurchase'
                , 'Recency'
                , 'Frequency'
                , 'Monetary'
                , 'NumberOfDaysAsCustomer'
                , 'Age_Group'
                , 'OfferAccepted'
                , 'IncomeSegment'], inplace=True, axis=1)

# %%
df.iloc[:5, :15]
# Out:
#     Education Marital_Status   Income  Kidhome  Teenhome  \
# 0         PhD        Married  55158.0        1         1
# 1    2n Cycle        Married  52203.0        0         0
# 2    2n Cycle        Married   7500.0        1         0
# 3  Graduation        Married   7500.0        1         0
# 4      Master        Married  82576.0        0         0
#
#    DaysSinceLastPurchase  AmountSpentOnWine  AmountSpentOnFruits  \
# 0                     72                293                    0
# 1                     36                488                   21
# 2                     98                  5                   17
# 3                     19                  7                    0
# 4                     66               1206                   55
#
#    AmountSpentOnMeatProducts  AmountSpentOnFishProducts  \
# 0                         87                          4
# 1                        238                         56
# 2                         17                         13
# 3                         12                         13
# 4                        445                        168
#
#    AmountSpentOnSweetProducts  AmountSpentOnGoldProducts  \
# 0                          11                         23
# 1                         108                         28
# 2                          14                         34
# 3                           7                         32
# 4                          18                         18
#
#    PurchasesMadeWithDiscounts  PurchasesMadeViaWeb  PurchasesMadeViaCatalog
# 0                           4                    7                        2
# 1                           1                    8                        7
# 2                           4                    2                        1
# 3                           5                    4                        1
# 4                           1                    2                        4

# %%
df.iloc[:5, 15:]
# Out:
#    PurchasesMadeDirectly  NumberOfVisitsToWebsitePerMonth  \
# 0                      5                                7
# 1                     11                                6
# 2                      3                                9
# 3                      2                                9
# 4                     12                                1
#
#    IsCampaign3Accepted  IsCampaign4Accepted  IsCampaign5Accepted  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    1                    0                    0
# 4                    0                    0                    1
#
#    IsCampaign1Accepted  IsCampaign2Accepted  HasComplainedInLast2Months  \
# 0                    0                    0                           0
# 1                    0                    0                           0
# 2                    0                    0                           0
# 3                    0                    0                           0
# 4                    0                    0                           0
#
#    IsLastCampaignAccepted  Age  RFM_Score      CustomerSegment  MonthStart  \
# 0                       1   55          8  Potential Loyalists  2012-07-01
# 1                       0   75         13            Champions  2012-07-01
# 2                       0   40          5              At Risk  2012-08-01
# 3                       1   49          9      Loyal Customers  2012-08-01
# 4                       0   66         11      Loyal Customers  2012-08-01
#
#    MonthLabel    RFM_Segment
# 0  Jul - 2012         Others
# 1  Jul - 2012      Champions
# 2  Aug - 2012       Sleeping
# 3  Aug - 2012  New Customers
# 4  Aug - 2012          Loyal

# %% [markdown]
# ### **Encoding Categorical Variables**

# %%
education_order = {'Basic': 1, '2n Cycle': 2, 'Graduation': 3, 'Master': 4, 'PhD': 5}
df['Education'] = df['Education'].map(education_order)

# %%
df.drop(columns=['Education'], inplace=True, axis=1)

# %%
df = pd.get_dummies(df, columns=['Marital_Status'], drop_first=True)
df['Marital_Status_Single'] = df['Marital_Status_Single'].astype(int)
df.rename(columns={'Marital_Status_Single': 'IsSingle'}, inplace=True)

# %% [markdown]
# ### **Feature Transformation: Scaling the features using StandardScaler**

# %%
flag_cols = ['Kidhome'
            , 'Teenhome'
            , 'IsCampaign1Accepted'
            , 'IsCampaign2Accepted'
            , 'IsCampaign3Accepted'
            , 'IsCampaign4Accepted'
            , 'IsCampaign5Accepted'
            , 'IsLastCampaignAccepted'
            , 'HasComplainedInLast2Months'
            , 'IsSingle']
cols_to_scale = ['Income'
                , 'DaysSinceLastPurchase'
                , 'AmountSpentOnWine'
                ,	'AmountSpentOnFruits'
                ,	'AmountSpentOnMeatProducts'
                ,	'AmountSpentOnFishProducts'
                ,	'AmountSpentOnSweetProducts'
                , 'AmountSpentOnGoldProducts'
                , 'PurchasesMadeWithDiscounts'
                ,	'PurchasesMadeViaWeb'
                ,	'PurchasesMadeViaCatalog'
                ,	'PurchasesMadeDirectly'
                ,	'NumberOfVisitsToWebsitePerMonth'
                , 'Age']

# %%
df['Id'] = range(1, len(df) + 1)

# %%
flags_df = df[['Id'] + flag_cols].copy()
to_scale_df = df[['Id'] + cols_to_scale].copy()

# %%
flags_df.head()
# Out:
#    Id  Kidhome  Teenhome  IsCampaign1Accepted  IsCampaign2Accepted  \
# 0   1        1         1                    0                    0
# 1   2        0         0                    0                    0
# 2   3        1         0                    0                    0
# 3   4        1         0                    0                    0
# 4   5        0         0                    0                    0
#
#    IsCampaign3Accepted  IsCampaign4Accepted  IsCampaign5Accepted  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    1                    0                    0
# 4                    0                    0                    1
#
#    IsLastCampaignAccepted  HasComplainedInLast2Months  IsSingle
# 0                       1                           0         0
# 1                       0                           0         0
# 2                       0                           0         0
# 3                       1                           0         0
# 4                       0                           0         0

# %%
to_scale_df.head()
# Out:
#    Id   Income  DaysSinceLastPurchase  AmountSpentOnWine  AmountSpentOnFruits  \
# 0   1  55158.0                     72                293                    0
# 1   2  52203.0                     36                488                   21
# 2   3   7500.0                     98                  5                   17
# 3   4   7500.0                     19                  7                    0
# 4   5  82576.0                     66               1206                   55
#
#    AmountSpentOnMeatProducts  AmountSpentOnFishProducts  \
# 0                         87                          4
# 1                        238                         56
# 2                         17                         13
# 3                         12                         13
# 4                        445                        168
#
#    AmountSpentOnSweetProducts  AmountSpentOnGoldProducts  \
# 0                          11                         23
# 1                         108                         28
# 2                          14                         34
# 3                           7                         32
# 4                          18                         18
#
#    PurchasesMadeWithDiscounts  PurchasesMadeViaWeb  PurchasesMadeViaCatalog  \
# 0                           4                    7                        2
# 1                           1                    8                        7
# 2                           4                    2                        1
# 3                           5                    4                        1
# 4                           1                    2                        4
#
#    PurchasesMadeDirectly  NumberOfVisitsToWebsitePerMonth  Age
# 0                      5                                7   55
# 1                     11                                6   75
# 2                      3                                9   40
# 3                      2                                9   49
# 4                     12                                1   66

# %%
scaler = StandardScaler()
scaled_array = scaler.fit_transform(to_scale_df[cols_to_scale])

# %%
scaled_df = pd.DataFrame(scaled_array, columns=cols_to_scale)

# %%
scaled_df['Id'] = to_scale_df['Id']

# %%
df_final = pd.merge(scaled_df, flags_df, on='Id')

# %%
df_final.drop('Id', axis=1, inplace=True)

# %%
df_final.to_csv('df_scaled_data_for_clustering.csv', index=False)
